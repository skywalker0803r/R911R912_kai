# %%
# %cd /content/drive/MyDrive/"Colab Notebooks"/MCUT/R911R912
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/MCUT/R911R912
# /content/drive/MyDrive/Colab Notebooks/MCUT/R911R912
#  ARO1_1.ipynb   ARO2_1.ipynb  'R911R912 _ARO1_R2.xlsx'
#  ARO1.ipynb     ARO2.ipynb    'R911R912 _明志蔡教授_R2.xlsx'

# %%
import pandas as pd
path = "R911R912 _明志蔡教授_R2.xlsx"
xls = pd.ExcelFile(path)
sheets = xls.sheet_names
display(sheets)
# Out:
# ['R911R912_TAG清單',
#  'R911R912_TAG相關錶點資料(停用)',
#  'R911R912_TAG相關錶點資料(X)',
#  '目標值(Y)相關錶點資料']

# %%
df = xls.parse(sheets[2])
df.columns.values[2] = "time"
df = df.iloc[:,2:]
for i in df.columns[1:]:
  df[i] = pd.to_numeric(df[i],errors='coerce')

df
# Out:
#                      time  ...  ARO2-LIMS-s919@Br.Index
# 0     2017-01-01 00:00:00  ...                      NaN
# 1     2017-01-01 01:00:00  ...                      NaN
# 2     2017-01-01 02:00:00  ...                      NaN
# 3     2017-01-01 03:00:00  ...                      NaN
# 4     2017-01-01 04:00:00  ...                      NaN
# ...                   ...  ...                      ...
# 38492 2021-05-23 20:00:00  ...                      NaN
# 38493 2021-05-23 21:00:00  ...                      NaN
# 38494 2021-05-23 22:00:00  ...                      NaN
# 38495 2021-05-23 23:00:00  ...                      NaN
# 38496 2021-05-24 00:00:00  ...                      NaN
#
# [38497 rows x 83 columns]

# %%
df.columns
# Out:
# Index(['time', 'ARO2-DCS-FI91304', 'ARO2-DCS-FI91401', 'ARO2-DCS-FI914A2',
#        'ARO2-DCS-FI914A3', 'ARO2-DCS-FI914B2', 'ARO2-DCS-FI914B3',
#        'ARO2-DCS-FI91501', 'ARO2-DCS-FI91502', 'ARO2-DCS-FI91503',
#        'ARO2-DCS-FI91504', 'ARO2-DCS-FI91601', 'ARO2-DCS-FI91602',
#        'ARO2-DCS-FI91701', 'ARO2-DCS-FI91702', 'ARO2-DCS-FI91704',
#        'ARO2-DCS-FI91705', 'ARO2-DCS-FI93201', 'ARO2-DCS-FI94701',
#        'ARO2-DCS-FI94702', 'ARO2-DCS-FIC91101', 'ARO2-DCS-FIC91102',
#        'ARO2-DCS-FIC91103', 'ARO2-DCS-FIC91104', 'ARO2-DCS-FIC91201',
#        'ARO2-DCS-FIC91202', 'ARO2-DCS-FIC91203', 'ARO2-DCS-FIC91204',
#        'ARO2-DCS-FIC91301', 'ARO2-DCS-FIC91302', 'ARO2-DCS-FIC91303',
#        'ARO2-DCS-PI91301', 'ARO2-DCS-PI91303', 'ARO2-DCS-PI913A1',
#        'ARO2-DCS-PI913B1', 'ARO2-DCS-PI91605', 'ARO2-DCS-PI91606',
#        'ARO2-DCS-PI91705', 'ARO2-DCS-PI91706', 'ARO2-DCS-PIC91102',
#        'ARO2-DCS-PIC91202', 'ARO2-DCS-PIC91302', 'ARO2-DCS-PIC91304',
#        '#900 LOADING.Value', 'ARO2-DCS-R911_2_A_FA', 'ARO2-DCS-R911_2_HF',
#        'ARO2-DCS-R911_2_L2_A', 'ARO2-DCS-R911_2_L3_A', 'ARO2-DCS-R911_2_L4_A',
#        'ARO2-DCS-R911_2_XF', 'ARO2-DCS-RV_CYC_T', 'ARO2-DCS-RV_STEP_T',
#        'ARO2-DCS-RV1_BED_P', 'ARO2-DCS-RV1_ZONE_P', 'ARO2-DCS-RV2_BED_P',
#        'ARO2-DCS-RV2_ZONE_P', 'ARO2-DCS-TI91101', 'ARO2-DCS-TI91102',
#        'ARO2-DCS-TI91103', 'ARO2-DCS-TI91201', 'ARO2-DCS-TI91202',
#        'ARO2-DCS-TI91203', 'ARO2-DCS-TI91401', 'ARO2-DCS-TI91501',
#        'ARO2-DCS-TI91502', 'ARO2-DCS-TI91602', 'ARO2-DCS-TI91701',
#        'ARO2-DCS-PDI91101', 'ARO2-DCS-PDI91201', 'ARO2-LIMS-S708@Br.Index',
#        'Unnamed: 72', 'ARO2-LIMS-S708@A9', 'Unnamed: 74',
#        'ARO2-LIMS-S708@A10+', 'Unnamed: 76', 'ARO2-LIMS-S708@Water',
#        'Unnamed: 78', 'ARO2-LIMS-S708@Sulfur', 'Unnamed: 80', '新增補充錶點',
#        'ARO2-LIMS-s919@A9', 'ARO2-LIMS-s919@A10+', 'ARO2-LIMS-s919@Br.Index'],
#       dtype='object')

# %%
x_col = df.columns[df.columns.str.contains('_L')].tolist()+df.columns[df.columns.str.contains('FA')].tolist()
x_col = x_col + ["ARO2-DCS-R911_2_HF"]

# %%
df_1 = xls.parse(sheets[3])
df_1.columns.values[1] = "time"
df_1 = df_1.iloc[:38497,1:]
for i in df_1.columns[1:]:
  df_1[i] = pd.to_numeric(df_1[i],errors='coerce')

df_1
# Out:
#                      time  ...  ARO2-DCS-PX@Recovery
# 0     2017-01-01 00:00:00  ...                   NaN
# 1     2017-01-01 01:00:00  ...                 96.28
# 2     2017-01-01 02:00:00  ...                   NaN
# 3     2017-01-01 03:00:00  ...                   NaN
# 4     2017-01-01 04:00:00  ...                   NaN
# ...                   ...  ...                   ...
# 38492 2021-05-23 20:00:00  ...                   NaN
# 38493 2021-05-23 21:00:00  ...                   NaN
# 38494 2021-05-23 22:00:00  ...                   NaN
# 38495 2021-05-23 23:00:00  ...                   NaN
# 38496 2021-05-24 00:00:00  ...                   NaN
#
# [38497 rows x 9 columns]

# %%
y_col= ["ARO2-LIMS-S708@PX", "ARO2-LIMS-s922@PX", "ARO2-LIMS-s922@MX",
    "ARO2-LIMS-S907@PX", "ARO2-LIMS-S905@PX", "ARO2-DCS-PX@Recovery", "time"]

col = x_col + y_col

df_2 = df[x_col].join(df_1[y_col])

df_2
# Out:
#        ARO2-DCS-R911_2_L2_A  ...                time
# 0                  0.315932  ... 2017-01-01 00:00:00
# 1                  0.315643  ... 2017-01-01 01:00:00
# 2                  0.315122  ... 2017-01-01 02:00:00
# 3                  0.314822  ... 2017-01-01 03:00:00
# 4                  0.314041  ... 2017-01-01 04:00:00
# ...                     ...  ...                 ...
# 38492              0.372907  ... 2021-05-23 20:00:00
# 38493              0.372907  ... 2021-05-23 21:00:00
# 38494              0.372907  ... 2021-05-23 22:00:00
# 38495              0.372907  ... 2021-05-23 23:00:00
# 38496              0.372907  ... 2021-05-24 00:00:00
#
# [38497 rows x 12 columns]

# %%
# Function to calculate missing values by column# Funct 
def missing_values_table(df):
  # Total missing values
  mis_val = df.isnull().sum()
  
  # Percentage of missing values
  mis_val_percent = 100 * df.isnull().sum() / len(df)
  
  # Make a table with the results
  mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
  
  # Rename the columns
  mis_val_table_ren_columns = mis_val_table.rename(
  columns = {0 : 'Missing Values', 1 : '% of Total Values'})
  
  # Sort the table by percentage of missing descending
  mis_val_table_ren_columns = mis_val_table_ren_columns[
      mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
  '% of Total Values', ascending=False).round(1)
  
  # Print some summary information
  print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
      "There are " + str(mis_val_table_ren_columns.shape[0]) +
        " columns that have missing values.")
  
  # Return the dataframe with missing information
  return mis_val_table_ren_columns

# Missing values statistics
missing_values = missing_values_table(df_2)
missing_values.head(20)
# Out:
# Your selected dataframe has 12 columns.
# There are 11 columns that have missing values.
#                       Missing Values  % of Total Values
# ARO2-LIMS-S905@PX              37164               96.5
# ARO2-LIMS-S907@PX              37162               96.5
# ARO2-DCS-PX@Recovery           37054               96.3
# ARO2-LIMS-s922@MX              34668               90.1
# ARO2-LIMS-s922@PX              34660               90.0
# ARO2-LIMS-S708@PX              34625               89.9
# ARO2-DCS-R911_2_L2_A               1                0.0
# ARO2-DCS-R911_2_L3_A               1                0.0
# ARO2-DCS-R911_2_L4_A               1                0.0
# ARO2-DCS-R911_2_A_FA               1                0.0
# ARO2-DCS-R911_2_HF                 1                0.0

# %%
# remove outliner
import numpy as np
for j in col[:-1]:
  mean = df_2[j].mean()
  std = df_2[j].std()
  outliner = []
  for i in range(len(df_2[j])):
    if (df_2.loc[i,j] > (mean - std*3) and df_2.loc[i,j] < (mean + std*3)):
      pass
    else:
      outliner = outliner + [i]

  df_2.loc[outliner, j] = np.nan

# %%
df_3 = df_2[x_col].dropna(axis="index").join(df_2.loc[df_2[x_col].dropna(axis="index").index.tolist(), y_col])

# %% [markdown]
# <font size = 5>1.Removing features with low variance</font>

# %%
import statistics as stat
print("df_3:")
for c in df_3.columns.tolist()[:11]:
    varianceNb = stat.variance(df_3[c].dropna(axis="index"))
    print(c,'變異數 : ', varianceNb)
# Out:
# df_3:
# ARO2-DCS-R911_2_L2_A 變異數 :  0.00047326504243806907
# ARO2-DCS-R911_2_L3_A 變異數 :  0.0002160348992043643
# ARO2-DCS-R911_2_L4_A 變異數 :  4.2652234637459104e-05
# ARO2-DCS-R911_2_A_FA 變異數 :  4.946303870026475e-05
# ARO2-DCS-R911_2_HF 變異數 :  0.3086050780502348
# ARO2-LIMS-S708@PX 變異數 :  0.10950634722738058
# ARO2-LIMS-s922@PX 變異數 :  0.0001361512612843882
# ARO2-LIMS-s922@MX 變異數 :  8798.445269370553
# ARO2-LIMS-S907@PX 變異數 :  18.53449107460427
# ARO2-LIMS-S905@PX 變異數 :  0.22239137350930274
# ARO2-DCS-PX@Recovery 變異數 :  1.3593158558453484

# %%
from sklearn.feature_selection import VarianceThreshold
#閥值(threshold)為0.16,表示其變異程度低於0.16就會被removed
print("df_3")
variance_x = VarianceThreshold(threshold = 0.16)
X_ss_vt=variance_x.fit_transform(df_3.iloc[:,:11].dropna(axis="index"))
X_ss_vt=pd.DataFrame(X_ss_vt)
X_ss_vt.head()
# Out:
# df_3
#             0       1          2      3      4
# 0  129.987991  1330.0  34.433998  0.409  96.28
# 1  129.987991  1345.0  37.900002  0.090  96.54
# 2  129.987991  1359.0  36.180000  0.830  96.56
# 3  129.987991  1365.0  35.590000  0.400  96.62
# 4  129.987991  1364.0  36.020000  0.850  96.57

# %% [markdown]
# <font size = 5>Univariate feature selection</font>

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_regression

#Suppose, we select 5 features with top 5 Fisher scores
selector = SelectKBest(f_regression, k = 5)
#New dataframe with the selected features for later use in the classifier. fit() method works too, if you want only the feature names and their corresponding scores
for i in y_col[:6]:
  X_new = selector.fit_transform(df_3.loc[df_3[i].notna(),x_col], df_3.loc[df_3[i].notna(), i])
  names = df_3.loc[df_3[i].notna(),x_col].columns.values[selector.get_support()]
  scores = selector.scores_[selector.get_support()]
  names_scores = list(zip(names, [i for j in range(5)], scores))
  ns_df = pd.DataFrame(data = names_scores, columns=['Feat_names', "target_name",'F_Scores'])
  #Sort the dataframe for better visualization
  if i == y_col[0]:
    ns_df_sorted = ns_df.sort_values(['F_Scores', 'Feat_names'], ascending = [False, True])
  else:
    ns_df_sorted = ns_df_sorted.append(ns_df.sort_values(['F_Scores', 'Feat_names'], ascending = [False, True]))

x_new = ns_df_sorted.reset_index(inplace = False)
x_new.iloc[:,1:]
# Out:
#               Feat_names           target_name      F_Scores
# 0   ARO2-DCS-R911_2_A_FA     ARO2-LIMS-S708@PX   1085.210726
# 1     ARO2-DCS-R911_2_HF     ARO2-LIMS-S708@PX    637.313225
# 2   ARO2-DCS-R911_2_L2_A     ARO2-LIMS-S708@PX    285.644565
# 3   ARO2-DCS-R911_2_L3_A     ARO2-LIMS-S708@PX    182.742762
# 4   ARO2-DCS-R911_2_L4_A     ARO2-LIMS-S708@PX    139.197388
# 5     ARO2-DCS-R911_2_HF     ARO2-LIMS-s922@PX    146.835381
# 6   ARO2-DCS-R911_2_L2_A     ARO2-LIMS-s922@PX     48.569564
# 7   ARO2-DCS-R911_2_L3_A     ARO2-LIMS-s922@PX     11.571587
# 8   ARO2-DCS-R911_2_L4_A     ARO2-LIMS-s922@PX      8.640259
# 9   ARO2-DCS-R911_2_A_FA     ARO2-LIMS-s922@PX      7.351138
# 10  ARO2-DCS-R911_2_A_FA     ARO2-LIMS-s922@MX   4296.732285
# 11  ARO2-DCS-R911_2_L3_A     ARO2-LIMS-s922@MX   3818.204405
# 12  ARO2-DCS-R911_2_L2_A     ARO2-LIMS-s922@MX   2586.441525
# 13    ARO2-DCS-R911_2_HF     ARO2-LIMS-s922@MX    957.582877
# 14  ARO2-DCS-R911_2_L4_A     ARO2-LIMS-s922@MX    352.614921
# 15  ARO2-DCS-R911_2_L2_A     ARO2-LIMS-S907@PX     25.611263
# 16  ARO2-DCS-R911_2_L3_A     ARO2-LIMS-S907@PX     22.929563
# 17  ARO2-DCS-R911_2_A_FA     ARO2-LIMS-S907@PX      9.718725
# 18    ARO2-DCS-R911_2_HF     ARO2-LIMS-S907@PX      7.182719
# 19  ARO2-DCS-R911_2_L4_A     ARO2-LIMS-S907@PX      5.830197
# 20  ARO2-DCS-R911_2_L2_A     ARO2-LIMS-S905@PX    123.494632
# 21  ARO2-DCS-R911_2_A_FA     ARO2-LIMS-S905@PX    105.724103
# 22  ARO2-DCS-R911_2_L3_A     ARO2-LIMS-S905@PX     86.131907
# 23    ARO2-DCS-R911_2_HF     ARO2-LIMS-S905@PX     34.652426
# 24  ARO2-DCS-R911_2_L4_A     ARO2-LIMS-S905@PX      7.455653
# 25  ARO2-DCS-R911_2_L2_A  ARO2-DCS-PX@Recovery  11672.648288
# 26  ARO2-DCS-R911_2_A_FA  ARO2-DCS-PX@Recovery   6344.093809
# 27  ARO2-DCS-R911_2_L3_A  ARO2-DCS-PX@Recovery   4084.571515
# 28    ARO2-DCS-R911_2_HF  ARO2-DCS-PX@Recovery    550.633696
# 29  ARO2-DCS-R911_2_L4_A  ARO2-DCS-PX@Recovery     65.812833

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression #F-value between label/feature for regression tasks.

print(df_3.loc[df_3[y_col[0]].notna(),x_col].shape)
model = SelectKBest(f_regression,3)
model.fit_transform(df_3.loc[df_3[y_col[0]].notna(),x_col], df_3.loc[df_3[y_col[0]].notna(), y_col[0]])
res = pd.DataFrame(index = x_col)
res["score"] = 0
for i in range(len(res.index)):
  res.iloc[i]["score"] = model.score_[i]
res.sort_values(by = "score", ascending = False)

# print(x_new.shape)
# x_new = pd.DataFrame(x_new)
# x_new.head()
# Out:
# (3848, 5)

# %% [markdown]
# <font size = 5>pearsonr</font>

# %%
from scipy.stats import pearsonr
X_COL = []
Y_COL = []
pearsonr_corr_list = []
p_value_list = []
for c in df_3.columns.tolist()[:5]:
  for i in y_col[:6]:
    #pearsonr的輸出分別為pearson相關係數和p-value
    pearsonr_corr ,p_value = pearsonr(df_3.loc[df_3[i].notna(),c], df_3.loc[df_3[i].notna(),i])
    X_COL.append(c)
    Y_COL.append(i)
    pearsonr_corr_list.append(pearsonr_corr)
    p_value_list.append(p_value)
    # print(c, " vs ", i, "pearsonr_corr:" ,pearsonr_corr,'p_value',p_value)

pd.DataFrame({"X":X_COL, "Y":Y_COL, "pearsonr_corr":pearsonr_corr_list, "p_value":p_value_list})
# Out:
#                        X                     Y  pearsonr_corr        p_value
# 0   ARO2-DCS-R911_2_L2_A     ARO2-LIMS-S708@PX       0.262937   7.185474e-62
# 1   ARO2-DCS-R911_2_L2_A     ARO2-LIMS-s922@PX       0.112121   3.739240e-12
# 2   ARO2-DCS-R911_2_L2_A     ARO2-LIMS-s922@MX       0.636089   0.000000e+00
# 3   ARO2-DCS-R911_2_L2_A     ARO2-LIMS-S907@PX      -0.139578   4.780710e-07
# 4   ARO2-DCS-R911_2_L2_A     ARO2-LIMS-S905@PX       0.292696   1.731841e-27
# 5   ARO2-DCS-R911_2_L2_A  ARO2-DCS-PX@Recovery      -0.943747   0.000000e+00
# 6   ARO2-DCS-R911_2_L3_A     ARO2-LIMS-S708@PX       0.212978   1.024593e-40
# 7   ARO2-DCS-R911_2_L3_A     ARO2-LIMS-s922@PX       0.054991   6.765607e-04
# 8   ARO2-DCS-R911_2_L3_A     ARO2-LIMS-s922@MX       0.707673   0.000000e+00
# 9   ARO2-DCS-R911_2_L3_A     ARO2-LIMS-S907@PX      -0.132203   1.874846e-06
# 10  ARO2-DCS-R911_2_L3_A     ARO2-LIMS-S905@PX       0.247673   6.692202e-20
# 11  ARO2-DCS-R911_2_L3_A  ARO2-DCS-PX@Recovery      -0.860398   0.000000e+00
# 12  ARO2-DCS-R911_2_L4_A     ARO2-LIMS-S708@PX       0.186892   1.388548e-31
# 13  ARO2-DCS-R911_2_L4_A     ARO2-LIMS-s922@PX       0.047536   3.307881e-03
# 14  ARO2-DCS-R911_2_L4_A     ARO2-LIMS-s922@MX      -0.291190   2.624124e-75
# 15  ARO2-DCS-R911_2_L4_A     ARO2-LIMS-S907@PX       0.067102   1.589189e-02
# 16  ARO2-DCS-R911_2_L4_A     ARO2-LIMS-S905@PX      -0.075000   6.408027e-03
# 17  ARO2-DCS-R911_2_L4_A  ARO2-DCS-PX@Recovery       0.209547   1.055562e-15
# 18  ARO2-DCS-R911_2_A_FA     ARO2-LIMS-S708@PX       0.469116  7.258953e-210
# 19  ARO2-DCS-R911_2_A_FA     ARO2-LIMS-s922@PX       0.043854   6.732057e-03
# 20  ARO2-DCS-R911_2_A_FA     ARO2-LIMS-s922@MX       0.728205   0.000000e+00
# 21  ARO2-DCS-R911_2_A_FA     ARO2-LIMS-S907@PX      -0.086506   1.864351e-03
# 22  ARO2-DCS-R911_2_A_FA     ARO2-LIMS-S905@PX       0.272505   6.593944e-24
# 23  ARO2-DCS-R911_2_A_FA  ARO2-DCS-PX@Recovery      -0.903184   0.000000e+00
# 24    ARO2-DCS-R911_2_HF     ARO2-LIMS-S708@PX       0.377031  3.021082e-130
# 25    ARO2-DCS-R911_2_HF     ARO2-LIMS-s922@PX      -0.192516   3.445056e-33
# 26    ARO2-DCS-R911_2_HF     ARO2-LIMS-s922@MX       0.448354  9.634287e-188
# 27    ARO2-DCS-R911_2_HF     ARO2-LIMS-S907@PX      -0.074441   7.454703e-03
# 28    ARO2-DCS-R911_2_HF     ARO2-LIMS-S905@PX       0.160057   4.993957e-09
# 29    ARO2-DCS-R911_2_HF  ARO2-DCS-PX@Recovery      -0.526867  2.633320e-103

# %% [markdown]
# <font size = 5>Model based ranking</font>

# %% [markdown]
# Ridge

# %%
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SelectFromModel
features_names = df_3[x_col].columns.tolist()
#model fit
for j in y_col[:6]:
  print(j, ":")
  ridge = Ridge()
  ridge.fit(df_3.loc[df_3[j].notna(), x_col], df_3.loc[df_3[j].notna(), j])
  #sort coef_
  coef_list=sorted(zip(map(lambda x: round(x,4), ridge.coef_.reshape(-1)),features_names),reverse=True)
  for i in coef_list:
    print(i)
  print()
# Out:
# ARO2-LIMS-S708@PX :
# (1.7297, 'ARO2-DCS-R911_2_A_FA')
# (1.2258, 'ARO2-DCS-R911_2_L4_A')
# (0.6133, 'ARO2-DCS-R911_2_L2_A')
# (0.4135, 'ARO2-DCS-R911_2_L3_A')
# (0.182, 'ARO2-DCS-R911_2_HF')
#
# ARO2-LIMS-s922@PX :
# (0.0779, 'ARO2-DCS-R911_2_L2_A')
# (0.0163, 'ARO2-DCS-R911_2_A_FA')
# (0.0146, 'ARO2-DCS-R911_2_L4_A')
# (0.0074, 'ARO2-DCS-R911_2_L3_A')
# (-0.0052, 'ARO2-DCS-R911_2_HF')
#
# ARO2-LIMS-s922@MX :
# (1167.2975, 'ARO2-DCS-R911_2_L3_A')
# (924.0691, 'ARO2-DCS-R911_2_L2_A')
# (493.4097, 'ARO2-DCS-R911_2_A_FA')
# (41.8325, 'ARO2-DCS-R911_2_HF')
# (-307.115, 'ARO2-DCS-R911_2_L4_A')
#
# ARO2-LIMS-S907@PX :
# (1.4898, 'ARO2-DCS-R911_2_L4_A')
# (-0.3346, 'ARO2-DCS-R911_2_A_FA')
# (-0.3728, 'ARO2-DCS-R911_2_HF')
# (-5.1812, 'ARO2-DCS-R911_2_L3_A')
# (-7.5357, 'ARO2-DCS-R911_2_L2_A')
#
# ARO2-LIMS-S905@PX :
# (1.7473, 'ARO2-DCS-R911_2_L2_A')
# (0.9528, 'ARO2-DCS-R911_2_L3_A')
# (0.4634, 'ARO2-DCS-R911_2_A_FA')
# (0.086, 'ARO2-DCS-R911_2_HF')
# (-0.1361, 'ARO2-DCS-R911_2_L4_A')
#
# ARO2-DCS-PX@Recovery :
# (1.0474, 'ARO2-DCS-R911_2_L4_A')
# (-0.7003, 'ARO2-DCS-R911_2_HF')
# (-3.9876, 'ARO2-DCS-R911_2_A_FA')
# (-9.3728, 'ARO2-DCS-R911_2_L3_A')
# (-13.9056, 'ARO2-DCS-R911_2_L2_A')

# %% [markdown]
# Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

features_names = df_3[x_col].columns.tolist()
for j in y_col[:6]:
  print(j, ":")
  if j == "ARO2-LIMS-S907@PX" or j == "ARO2-DCS-PX@Recovery":
    lasso = Lasso(alpha=0.001 ,positive=True)
  elif j == "ARO2-LIMS-s922@PX":
    lasso = Lasso(alpha=0.00001 ,positive=True)
  else:
    lasso = Lasso(alpha=0.01 ,positive=True)
  
  lasso.fit(df_3.loc[df_3[j].notna(), x_col], df_3.loc[df_3[j].notna(), j])
  coef_list=sorted(zip(map(lambda x: round(x,4), lasso.coef_.reshape(-1)),features_names),reverse=True)
  for i in coef_list:
    print(i)

  print()
# Out:
# ARO2-LIMS-S708@PX :
# (0.1792, 'ARO2-DCS-R911_2_HF')
# (0.0, 'ARO2-DCS-R911_2_L4_A')
# (0.0, 'ARO2-DCS-R911_2_L3_A')
# (0.0, 'ARO2-DCS-R911_2_L2_A')
# (0.0, 'ARO2-DCS-R911_2_A_FA')
#
# ARO2-LIMS-s922@PX :
# (0.0394, 'ARO2-DCS-R911_2_L2_A')
# (0.0, 'ARO2-DCS-R911_2_L4_A')
# (0.0, 'ARO2-DCS-R911_2_L3_A')
# (0.0, 'ARO2-DCS-R911_2_HF')
# (0.0, 'ARO2-DCS-R911_2_A_FA')
#
# ARO2-LIMS-s922@MX :
# (3463.7481, 'ARO2-DCS-R911_2_A_FA')
# (2923.2731, 'ARO2-DCS-R911_2_L3_A')
# (24.3461, 'ARO2-DCS-R911_2_HF')
# (0.0, 'ARO2-DCS-R911_2_L4_A')
# (0.0, 'ARO2-DCS-R911_2_L2_A')
#
# ARO2-LIMS-S907@PX :
# (18.6636, 'ARO2-DCS-R911_2_L4_A')
# (0.0, 'ARO2-DCS-R911_2_L3_A')
# (0.0, 'ARO2-DCS-R911_2_L2_A')
# (0.0, 'ARO2-DCS-R911_2_HF')
# (0.0, 'ARO2-DCS-R911_2_A_FA')
#
# ARO2-LIMS-S905@PX :
# (0.0984, 'ARO2-DCS-R911_2_HF')
# (0.0, 'ARO2-DCS-R911_2_L4_A')
# (0.0, 'ARO2-DCS-R911_2_L3_A')
# (0.0, 'ARO2-DCS-R911_2_L2_A')
# (0.0, 'ARO2-DCS-R911_2_A_FA')
#
# ARO2-DCS-PX@Recovery :
# (11.7912, 'ARO2-DCS-R911_2_L4_A')
# (0.0, 'ARO2-DCS-R911_2_L3_A')
# (0.0, 'ARO2-DCS-R911_2_L2_A')
# (0.0, 'ARO2-DCS-R911_2_HF')
# (0.0, 'ARO2-DCS-R911_2_A_FA')
