# %%
# %cd /content/drive/MyDrive/"Colab Notebooks"/MCUT/R911R912
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/Colab Notebooks/MCUT/R911R912
# /content/drive/MyDrive/Colab Notebooks/MCUT/R911R912
#  ARO1_pearsonr_corr.csv		       'ARO2_可控_Feature Selection.ipynb'
# 'ARO1_不可控_Feature Selection.ipynb'   ARO2_可控_Xgboost.ipynb
#  ARO1_不可控_Xgboost.ipynb	       'R911R912 _ARO1_R2.xlsx'
# 'ARO1_可控_Feature Selection.ipynb'     R911R912.pptx
#  ARO1_可控_Xgboost.ipynb	       'R911R912 _明志蔡教授_R2.xlsx'
#  ARO2_pearsonr_corr.csv		        test.csv
# 'ARO2_不可控_Feature Selection.ipynb'   Untitled0.ipynb
#  ARO2_不可控_Xgboost.ipynb

# %%
import pandas as pd
path = "R911R912 _明志蔡教授_R2.xlsx"
xls = pd.ExcelFile(path)
sheets = xls.sheet_names
display(sheets)
# Out:
# ['R911R912_TAG清單',
#  'R911R912_TAG相關錶點資料(停用)',
#  'R911R912_TAG相關錶點資料(X)',
#  '目標值(Y)相關錶點資料']

# %%
df = xls.parse(sheets[2])
df.columns.values[2] = "time"
df = df.iloc[:,2:]
for i in df.columns[1:]:
  df[i] = pd.to_numeric(df[i],errors='coerce')

df
# Out:
#                      time  ...  ARO2-LIMS-s919@Br.Index
# 0     2017-01-01 00:00:00  ...                      NaN
# 1     2017-01-01 01:00:00  ...                      NaN
# 2     2017-01-01 02:00:00  ...                      NaN
# 3     2017-01-01 03:00:00  ...                      NaN
# 4     2017-01-01 04:00:00  ...                      NaN
# ...                   ...  ...                      ...
# 38492 2021-05-23 20:00:00  ...                      NaN
# 38493 2021-05-23 21:00:00  ...                      NaN
# 38494 2021-05-23 22:00:00  ...                      NaN
# 38495 2021-05-23 23:00:00  ...                      NaN
# 38496 2021-05-24 00:00:00  ...                      NaN
#
# [38497 rows x 83 columns]

# %%
df.columns
# Out:
# Index(['time', 'ARO2-DCS-FI91304', 'ARO2-DCS-FI91401', 'ARO2-DCS-FI914A2',
#        'ARO2-DCS-FI914A3', 'ARO2-DCS-FI914B2', 'ARO2-DCS-FI914B3',
#        'ARO2-DCS-FI91501', 'ARO2-DCS-FI91502', 'ARO2-DCS-FI91503',
#        'ARO2-DCS-FI91504', 'ARO2-DCS-FI91601', 'ARO2-DCS-FI91602',
#        'ARO2-DCS-FI91701', 'ARO2-DCS-FI91702', 'ARO2-DCS-FI91704',
#        'ARO2-DCS-FI91705', 'ARO2-DCS-FI93201', 'ARO2-DCS-FI94701',
#        'ARO2-DCS-FI94702', 'ARO2-DCS-FIC91101', 'ARO2-DCS-FIC91102',
#        'ARO2-DCS-FIC91103', 'ARO2-DCS-FIC91104', 'ARO2-DCS-FIC91201',
#        'ARO2-DCS-FIC91202', 'ARO2-DCS-FIC91203', 'ARO2-DCS-FIC91204',
#        'ARO2-DCS-FIC91301', 'ARO2-DCS-FIC91302', 'ARO2-DCS-FIC91303',
#        'ARO2-DCS-PI91301', 'ARO2-DCS-PI91303', 'ARO2-DCS-PI913A1',
#        'ARO2-DCS-PI913B1', 'ARO2-DCS-PI91605', 'ARO2-DCS-PI91606',
#        'ARO2-DCS-PI91705', 'ARO2-DCS-PI91706', 'ARO2-DCS-PIC91102',
#        'ARO2-DCS-PIC91202', 'ARO2-DCS-PIC91302', 'ARO2-DCS-PIC91304',
#        '#900 LOADING.Value', 'ARO2-DCS-R911_2_A_FA', 'ARO2-DCS-R911_2_HF',
#        'ARO2-DCS-R911_2_L2_A', 'ARO2-DCS-R911_2_L3_A', 'ARO2-DCS-R911_2_L4_A',
#        'ARO2-DCS-R911_2_XF', 'ARO2-DCS-RV_CYC_T', 'ARO2-DCS-RV_STEP_T',
#        'ARO2-DCS-RV1_BED_P', 'ARO2-DCS-RV1_ZONE_P', 'ARO2-DCS-RV2_BED_P',
#        'ARO2-DCS-RV2_ZONE_P', 'ARO2-DCS-TI91101', 'ARO2-DCS-TI91102',
#        'ARO2-DCS-TI91103', 'ARO2-DCS-TI91201', 'ARO2-DCS-TI91202',
#        'ARO2-DCS-TI91203', 'ARO2-DCS-TI91401', 'ARO2-DCS-TI91501',
#        'ARO2-DCS-TI91502', 'ARO2-DCS-TI91602', 'ARO2-DCS-TI91701',
#        'ARO2-DCS-PDI91101', 'ARO2-DCS-PDI91201', 'ARO2-LIMS-S708@Br.Index',
#        'Unnamed: 72', 'ARO2-LIMS-S708@A9', 'Unnamed: 74',
#        'ARO2-LIMS-S708@A10+', 'Unnamed: 76', 'ARO2-LIMS-S708@Water',
#        'Unnamed: 78', 'ARO2-LIMS-S708@Sulfur', 'Unnamed: 80', '新增補充錶點',
#        'ARO2-LIMS-s919@A9', 'ARO2-LIMS-s919@A10+', 'ARO2-LIMS-s919@Br.Index'],
#       dtype='object')

# %%
df_1 = xls.parse(sheets[3])
df_1.columns.values[1] = "time"
df_1 = df_1.iloc[:38497,1:]
for i in df_1.columns[1:]:
  df_1[i] = pd.to_numeric(df_1[i],errors='coerce')

df_1
# Out:
#                      time  ...  ARO2-DCS-PX@Recovery
# 0     2017-01-01 00:00:00  ...                   NaN
# 1     2017-01-01 01:00:00  ...                 96.28
# 2     2017-01-01 02:00:00  ...                   NaN
# 3     2017-01-01 03:00:00  ...                   NaN
# 4     2017-01-01 04:00:00  ...                   NaN
# ...                   ...  ...                   ...
# 38492 2021-05-23 20:00:00  ...                   NaN
# 38493 2021-05-23 21:00:00  ...                   NaN
# 38494 2021-05-23 22:00:00  ...                   NaN
# 38495 2021-05-23 23:00:00  ...                   NaN
# 38496 2021-05-24 00:00:00  ...                   NaN
#
# [38497 rows x 9 columns]

# %%
x_col = ["ARO2-DCS-FI914B2", "ARO2-DCS-FI914B3", "ARO2-DCS-FI91601", "ARO2-DCS-FI91701",
     "ARO2-LIMS-S708@Br.Index", "ARO2-LIMS-S708@A9","ARO2-LIMS-S708@A10+", 
     "ARO2-LIMS-S708@Water", "ARO2-LIMS-S708@Sulfur", "ARO2-DCS-PDI91101", "ARO2-DCS-PDI91201"]


y_col= ["ARO2-LIMS-s922@PX", "ARO2-LIMS-s922@MX",
    "ARO2-LIMS-S907@PX", "ARO2-LIMS-S905@PX", "ARO2-DCS-PX@Recovery"]

col = x_col + y_col

df_2 = df[x_col].join(df_1[y_col])

y_col = x_col[9:] + y_col
x_col = x_col[:9]

df_2
# Out:
#        ARO2-DCS-FI914B2  ...  ARO2-DCS-PX@Recovery
# 0           1487.988403  ...                   NaN
# 1           1483.480591  ...                 96.28
# 2           2071.642578  ...                   NaN
# 3           2058.044189  ...                   NaN
# 4           2066.448975  ...                   NaN
# ...                 ...  ...                   ...
# 38492       1191.802246  ...                   NaN
# 38493       1196.045898  ...                   NaN
# 38494       1190.460815  ...                   NaN
# 38495       1851.466797  ...                   NaN
# 38496       1856.745605  ...                   NaN
#
# [38497 rows x 16 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

df_2[["ARO2-DCS-FI914B2", "ARO2-DCS-FI914B3", "ARO2-DCS-FI91601", "ARO2-DCS-FI91701"]] = df_2[["ARO2-DCS-FI914B2", "ARO2-DCS-FI914B3", "ARO2-DCS-FI91601", "ARO2-DCS-FI91701"]] / 885450

scaler = MinMaxScaler()
scaler.fit(df_2[x_col])
df_2[x_col] = scaler.transform(df_2[x_col])

# %%
# Function to calculate missing values by column# Funct 
def missing_values_table(df):
  # Total missing values
  mis_val = df.isnull().sum()
  
  # Percentage of missing values
  mis_val_percent = 100 * df.isnull().sum() / len(df)
  
  # Make a table with the results
  mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
  
  # Rename the columns
  mis_val_table_ren_columns = mis_val_table.rename(
  columns = {0 : 'Missing Values', 1 : '% of Total Values'})
  
  # Sort the table by percentage of missing descending
  mis_val_table_ren_columns = mis_val_table_ren_columns[
      mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
  '% of Total Values', ascending=False).round(1)
  
  # Print some summary information
  print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
      "There are " + str(mis_val_table_ren_columns.shape[0]) +
        " columns that have missing values.")
  
  # Return the dataframe with missing information
  return mis_val_table_ren_columns

# Missing values statistics
missing_values = missing_values_table(df_2)
missing_values.head(20)
# Out:
# Your selected dataframe has 16 columns.
# There are 16 columns that have missing values.
#                          Missing Values  % of Total Values
# ARO2-LIMS-S708@Sulfur             37164               96.5
# ARO2-LIMS-S905@PX                 37164               96.5
# ARO2-LIMS-S907@PX                 37162               96.5
# ARO2-LIMS-S708@Br.Index           37137               96.5
# ARO2-DCS-PX@Recovery              37054               96.3
# ARO2-LIMS-s922@MX                 34668               90.1
# ARO2-LIMS-s922@PX                 34660               90.0
# ARO2-LIMS-S708@Water              34654               90.0
# ARO2-LIMS-S708@A10+               34632               90.0
# ARO2-LIMS-S708@A9                 34617               89.9
# ARO2-DCS-FI914B2                      1                0.0
# ARO2-DCS-FI914B3                      1                0.0
# ARO2-DCS-FI91601                      1                0.0
# ARO2-DCS-FI91701                      1                0.0
# ARO2-DCS-PDI91101                     1                0.0
# ARO2-DCS-PDI91201                     1                0.0

# %%
# remove outliner
import numpy as np
for j in col:
  mean = df_2[j].mean()
  std = df_2[j].std()
  outliner = []
  for i in range(len(df_2[j])):
    if (df_2.loc[i,j] > (mean - std*3) and df_2.loc[i,j] < (mean + std*3)):
      pass
    else:
      outliner = outliner + [i]

  df_2.loc[outliner, j] = np.nan

# %%
df_3 = df_2[x_col].dropna(axis="index").join(df_2.loc[df_2[x_col].dropna(axis="index").index.tolist(), y_col])
df_3
# Out:
#        ARO2-DCS-FI914B2  ...  ARO2-DCS-PX@Recovery
# 1              0.644992  ...                 96.28
# 25             0.624021  ...                 96.54
# 49             0.770612  ...                 96.56
# 73             0.911511  ...                 96.62
# 97             0.632538  ...                 96.57
# ...                 ...  ...                   ...
# 38377          0.637088  ...                 93.49
# 38401          0.812156  ...                 93.73
# 38425          0.901459  ...                 93.47
# 38449          0.617846  ...                 93.59
# 38473          0.635246  ...                 93.67
#
# [1089 rows x 16 columns]

# %% [markdown]
# <font size = 5>1.Removing features with low variance</font>

# %%
import statistics as stat
print("df_3:")
for c in df_3.columns.tolist():
    varianceNb = stat.variance(df_3[c].dropna(axis="index"))
    print(c,'變異數 : ', varianceNb)
# Out:
# df_3:
# ARO2-DCS-FI914B2 變異數 :  0.018415553705317996
# ARO2-DCS-FI914B3 變異數 :  0.01788538015806664
# ARO2-DCS-FI91601 變異數 :  0.002241607331424342
# ARO2-DCS-FI91701 變異數 :  0.0020709344147724004
# ARO2-LIMS-S708@Br.Index 變異數 :  0.01024229006841433
# ARO2-LIMS-S708@A9 變異數 :  0.0014840773414905042
# ARO2-LIMS-S708@A10+ 變異數 :  0.0009372423846430972
# ARO2-LIMS-S708@Water 變異數 :  8.772038355028348e-08
# ARO2-LIMS-S708@Sulfur 變異數 :  0.0037462435962135653
# ARO2-DCS-PDI91101 變異數 :  0.08476311793250323
# ARO2-DCS-PDI91201 變異數 :  0.09408585784138261
# ARO2-LIMS-s922@PX 變異數 :  1.989816556739923
# ARO2-LIMS-s922@MX 變異數 :  88909894.3480265
# ARO2-LIMS-S907@PX 變異數 :  50.84115167247562
# ARO2-LIMS-S905@PX 變異數 :  2.657817535228892
# ARO2-DCS-PX@Recovery 變異數 :  1.2707202933124082

# %%
from sklearn.feature_selection import VarianceThreshold
#閥值(threshold)為0.16,表示其變異程度低於0.16就會被removed
print("df_3")
variance_x = VarianceThreshold(threshold = 0.16)
X_ss_vt=variance_x.fit_transform(df_2.iloc[:,:11].dropna(axis="index"))
X_ss_vt=pd.DataFrame(X_ss_vt)
X_ss_vt.head()
# Out:
# df_3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-2d705f6d03ae> in <module>()
#       3 print("df_3")
#       4 variance_x = VarianceThreshold(threshold = 0.16)
# ----> 5 X_ss_vt=variance_x.fit_transform(df_2.iloc[:,:11].dropna(axis="index"))
#       6 X_ss_vt=pd.DataFrame(X_ss_vt)
#       7 X_ss_vt.head()
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     845         if y is None:
#     846             # fit method of arity 1 (unsupervised transformation)
# --> 847             return self.fit(X, **fit_params).transform(X)
#     848         else:
#     849             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_variance_threshold.py in fit(self, X, y)
#     118             if X.shape[0] == 1:
#     119                 msg += " (X contains only one sample)"
# --> 120             raise ValueError(msg.format(self.threshold))
#     121
#     122         return self
#
# ValueError: No feature in X meets the variance threshold 0.16000

# %% [markdown]
# <font size = 5>Univariate feature selection</font>

# %%
df_3.loc[df_3[i].notna(),x_col]
# Out:
#        ARO2-DCS-FI914B2  ...  ARO2-LIMS-S708@Sulfur
# 1              0.644992  ...               0.034843
# 25             0.624021  ...               0.061556
# 49             0.770612  ...               0.075494
# 73             0.911511  ...               0.087108
# 97             0.632538  ...               0.096400
# ...                 ...  ...                    ...
# 38377          0.637088  ...               0.016260
# 38401          0.812156  ...               0.186992
# 38425          0.901459  ...               0.053426
# 38449          0.617846  ...               0.044135
# 38473          0.635246  ...               0.052265
#
# [1089 rows x 9 columns]

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_regression

#Suppose, we select 5 features with top 5 Fisher scores
selector = SelectKBest(f_regression, k = 5)
#New dataframe with the selected features for later use in the classifier. fit() method works too, if you want only the feature names and their corresponding scores
for i in y_col:
  X_new = selector.fit_transform(df_3.loc[df_3[i].notna(),x_col], df_3.loc[df_3[i].notna(), i])
  names = df_3.loc[df_3[i].notna(),x_col].columns.values[selector.get_support()]
  scores = selector.scores_[selector.get_support()]
  names_scores = list(zip(names, [i for j in range(5)], scores))
  ns_df = pd.DataFrame(data = names_scores, columns=['Feat_names', "target_name",'F_Scores'])
  #Sort the dataframe for better visualization
  if i == y_col[0]:
    ns_df_sorted = ns_df.sort_values(['F_Scores', 'Feat_names'], ascending = [False, True])
  else:
    ns_df_sorted = ns_df_sorted.append(ns_df.sort_values(['F_Scores', 'Feat_names'], ascending = [False, True]))

x_new = ns_df_sorted.reset_index(inplace = False)
x_new.iloc[:,1:]
# Out:
#                  Feat_names           target_name    F_Scores
# 0          ARO2-DCS-FI91701     ARO2-DCS-PDI91101  802.996704
# 1          ARO2-DCS-FI91601     ARO2-DCS-PDI91101  627.568661
# 2         ARO2-LIMS-S708@A9     ARO2-DCS-PDI91101   11.581101
# 3   ARO2-LIMS-S708@Br.Index     ARO2-DCS-PDI91101    5.963403
# 4       ARO2-LIMS-S708@A10+     ARO2-DCS-PDI91101    3.403345
# 5          ARO2-DCS-FI91601     ARO2-DCS-PDI91201  626.067114
# 6          ARO2-DCS-FI91701     ARO2-DCS-PDI91201  601.348530
# 7          ARO2-DCS-FI914B3     ARO2-DCS-PDI91201   17.899666
# 8   ARO2-LIMS-S708@Br.Index     ARO2-DCS-PDI91201   10.987409
# 9      ARO2-LIMS-S708@Water     ARO2-DCS-PDI91201    7.630949
# 10         ARO2-DCS-FI91601     ARO2-LIMS-s922@PX   32.053644
# 11         ARO2-DCS-FI91701     ARO2-LIMS-s922@PX   28.830484
# 12         ARO2-DCS-FI914B3     ARO2-LIMS-s922@PX    1.376699
# 13     ARO2-LIMS-S708@Water     ARO2-LIMS-s922@PX    1.111850
# 14         ARO2-DCS-FI914B2     ARO2-LIMS-s922@PX    0.644267
# 15         ARO2-DCS-FI91601     ARO2-LIMS-s922@MX   32.934232
# 16         ARO2-DCS-FI91701     ARO2-LIMS-s922@MX   28.625792
# 17     ARO2-LIMS-S708@Water     ARO2-LIMS-s922@MX    1.359482
# 18         ARO2-DCS-FI914B3     ARO2-LIMS-s922@MX    1.328520
# 19         ARO2-DCS-FI914B2     ARO2-LIMS-s922@MX    0.641411
# 20    ARO2-LIMS-S708@Sulfur     ARO2-LIMS-S907@PX    8.053983
# 21  ARO2-LIMS-S708@Br.Index     ARO2-LIMS-S907@PX    5.282306
# 22         ARO2-DCS-FI91601     ARO2-LIMS-S907@PX    3.522821
# 23         ARO2-DCS-FI914B3     ARO2-LIMS-S907@PX    2.071565
# 24        ARO2-LIMS-S708@A9     ARO2-LIMS-S907@PX    1.431069
# 25  ARO2-LIMS-S708@Br.Index     ARO2-LIMS-S905@PX    6.916073
# 26    ARO2-LIMS-S708@Sulfur     ARO2-LIMS-S905@PX    2.686883
# 27         ARO2-DCS-FI914B2     ARO2-LIMS-S905@PX    0.686594
# 28     ARO2-LIMS-S708@Water     ARO2-LIMS-S905@PX    0.230540
# 29         ARO2-DCS-FI91601     ARO2-LIMS-S905@PX    0.227786
# 30         ARO2-DCS-FI91601  ARO2-DCS-PX@Recovery  501.313118
# 31     ARO2-LIMS-S708@Water  ARO2-DCS-PX@Recovery  110.028626
# 32  ARO2-LIMS-S708@Br.Index  ARO2-DCS-PX@Recovery   38.212112
# 33    ARO2-LIMS-S708@Sulfur  ARO2-DCS-PX@Recovery   34.763034
# 34         ARO2-DCS-FI91701  ARO2-DCS-PX@Recovery   11.241968

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression #F-value between label/feature for regression tasks.

print(df_3.loc[df_3[y_col[0]].notna(),x_col].shape)
model = SelectKBest(f_regression,3)
model.fit_transform(df_3.loc[df_3[x_col and y_col[0]].notna(), x_col].dropna(axis="index"), df_3.loc[df_3[x_col and y_col[0]].notna(), x_col + [y_col[0]]].dropna(axis="index")[y_col[0]])
res = pd.DataFrame(index = x_col)
res["score"] = 0
for i in range(len(res.index)):
  res.iloc[i]["score"] = model.scores_[i]

res.sort_values(by = "score", ascending = False)
# print(df_2.loc[df_2[y_col[0]].notna(),x_col].shape)
# x_new = SelectKBest(f_regression,3).fit_transform(df_2.loc[df_2[x_col and y_col[0]].notna(), x_col].dropna(axis="index"), df_2.loc[df_2[x_col and y_col[0]].notna(), x_col + [y_col[0]]].dropna(axis="index")[y_col[0]])
# print(x_new.shape)
# x_new = pd.DataFrame(x_new)
# x_new.head()
# Out:
# (998, 11)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-641c71911a50> in <module>()
#       3
#       4 print(df_3.loc[df_3[y_col[0]].notna(),x_col].shape)
# ----> 5 model = SelectKBest(f_regression,3)
#       6 model.fit_transform(df_3.loc[df_3[x_col and y_col[0]].notna(), x_col].dropna(axis="index"), df_3.loc[df_3[x_col and y_col[0]].notna(), x_col + [y_col[0]]].dropna(axis="index")[y_col[0]])
#       7 res = pd.DataFrame(index = x_col)
#
# TypeError: __init__() takes from 1 to 2 positional arguments but 3 were given

# %% [markdown]
# <font size = 5>pearsonr</font>

# %%
from scipy.stats import pearsonr
X_COL = []
Y_COL = []
pearsonr_corr_list = []
p_value_list = []
for i in y_col:
  for c in df_3.columns.tolist()[:11]:
    #pearsonr的輸出分別為pearson相關係數和p-value
    pearsonr_corr ,p_value = pearsonr(df_3.loc[df_3[i].notna(),c], df_3.loc[df_3[i].notna(),i])
    X_COL.append(c)
    Y_COL.append(i)
    pearsonr_corr_list.append(pearsonr_corr)
    p_value_list.append(p_value)
    # print(c, " vs ", i, "pearsonr_corr:" ,pearsonr_corr,'p_value',p_value)

data = pd.DataFrame({"X":X_COL, "Y":Y_COL, "pearsonr_corr":pearsonr_corr_list, "p_value":p_value_list})
data.to_csv("ARO2_pearsonr_corr.csv")
data
# Out:
#                           X                     Y  pearsonr_corr        p_value
# 0          ARO2-DCS-FI914B2     ARO2-DCS-PDI91101       0.053077   7.998921e-02
# 1          ARO2-DCS-FI914B3     ARO2-DCS-PDI91101      -0.033801   2.650711e-01
# 2          ARO2-DCS-FI91601     ARO2-DCS-PDI91101       0.604997  1.068718e-109
# 3          ARO2-DCS-FI91701     ARO2-DCS-PDI91101       0.651818  1.007486e-132
# 4   ARO2-LIMS-S708@Br.Index     ARO2-DCS-PDI91101       0.073866   1.476436e-02
# ..                      ...                   ...            ...            ...
# 72      ARO2-LIMS-S708@A10+  ARO2-DCS-PX@Recovery       0.085221   6.358170e-03
# 73     ARO2-LIMS-S708@Water  ARO2-DCS-PX@Recovery       0.311763   1.613251e-24
# 74    ARO2-LIMS-S708@Sulfur  ARO2-DCS-PX@Recovery       0.181372   5.054808e-09
# 75        ARO2-DCS-PDI91101  ARO2-DCS-PX@Recovery      -0.038208   2.218541e-01
# 76        ARO2-DCS-PDI91201  ARO2-DCS-PX@Recovery       0.116245   1.930513e-04
#
# [77 rows x 4 columns]

# %% [markdown]
# <font size = 5>Model based ranking</font>

# %% [markdown]
# Ridge

# %%
from sklearn.linear_model import Ridge
from sklearn.feature_selection import SelectFromModel
features_names = df_3[x_col].columns.tolist()
#model fit
for j in y_col:
  print(j, ":")
  ridge = Ridge()
  ridge.fit(df_3.loc[df_3[j].notna(), x_col], df_3.loc[df_3[j].notna(), j])
  #sort coef_
  coef_list=sorted(zip(map(lambda x: round(x,4), ridge.coef_.reshape(-1)),features_names),reverse=True)
  for i in coef_list:
    print(i)
  print()
# Out:
# ARO2-DCS-PDI91101 :
# (1.9541, 'ARO2-DCS-FI91701')
# (1.4159, 'ARO2-DCS-FI91601')
# (0.3973, 'ARO2-LIMS-S708@A9')
# (0.0564, 'ARO2-LIMS-S708@Br.Index')
# (0.0546, 'ARO2-LIMS-S708@Sulfur')
# (0.0336, 'ARO2-DCS-FI914B2')
# (-0.0041, 'ARO2-LIMS-S708@Water')
# (-0.1478, 'ARO2-DCS-FI914B3')
# (-0.2789, 'ARO2-LIMS-S708@A10+')
#
# ARO2-DCS-PDI91201 :
# (1.7579, 'ARO2-DCS-FI91601')
# (1.5658, 'ARO2-DCS-FI91701')
# (0.2008, 'ARO2-DCS-FI914B3')
# (0.1674, 'ARO2-LIMS-S708@A9')
# (0.1452, 'ARO2-LIMS-S708@Br.Index')
# (0.1055, 'ARO2-LIMS-S708@A10+')
# (0.0536, 'ARO2-DCS-FI914B2')
# (0.0047, 'ARO2-LIMS-S708@Water')
# (-0.0995, 'ARO2-LIMS-S708@Sulfur')
#
# ARO2-LIMS-s922@PX :
# (2.4394, 'ARO2-DCS-FI91601')
# (2.0383, 'ARO2-DCS-FI91701')
# (0.1711, 'ARO2-DCS-FI914B2')
# (0.1702, 'ARO2-LIMS-S708@A9')
# (0.1204, 'ARO2-LIMS-S708@Sulfur')
# (0.0891, 'ARO2-LIMS-S708@A10+')
# (0.0079, 'ARO2-LIMS-S708@Water')
# (-0.3748, 'ARO2-LIMS-S708@Br.Index')
# (-0.4703, 'ARO2-DCS-FI914B3')
#
# ARO2-LIMS-s922@MX :
# (3134.9904, 'ARO2-DCS-FI914B3')
# (2561.7639, 'ARO2-LIMS-S708@Br.Index')
# (-61.6368, 'ARO2-LIMS-S708@Water')
# (-667.2919, 'ARO2-LIMS-S708@A10+')
# (-974.5443, 'ARO2-LIMS-S708@Sulfur')
# (-1178.637, 'ARO2-DCS-FI914B2')
# (-1329.2324, 'ARO2-LIMS-S708@A9')
# (-13174.6023, 'ARO2-DCS-FI91701')
# (-16827.8857, 'ARO2-DCS-FI91601')
#
# ARO2-LIMS-S907@PX :
# (7.569, 'ARO2-LIMS-S708@Sulfur')
# (7.0851, 'ARO2-DCS-FI91601')
# (2.9609, 'ARO2-LIMS-S708@A9')
# (1.2517, 'ARO2-DCS-FI914B2')
# (0.9012, 'ARO2-LIMS-S708@A10+')
# (0.0351, 'ARO2-LIMS-S708@Water')
# (-1.7443, 'ARO2-DCS-FI91701')
# (-2.6322, 'ARO2-DCS-FI914B3')
# (-4.1728, 'ARO2-LIMS-S708@Br.Index')
#
# ARO2-LIMS-S905@PX :
# (1.1997, 'ARO2-LIMS-S708@Br.Index')
# (0.3772, 'ARO2-LIMS-S708@A9')
# (0.3405, 'ARO2-DCS-FI914B2')
# (0.2191, 'ARO2-DCS-FI91701')
# (0.0379, 'ARO2-DCS-FI914B3')
# (-0.003, 'ARO2-LIMS-S708@Water')
# (-0.1567, 'ARO2-LIMS-S708@A10+')
# (-0.6243, 'ARO2-DCS-FI91601')
# (-0.9175, 'ARO2-LIMS-S708@Sulfur')
#
# ARO2-DCS-PX@Recovery :
# (9.3541, 'ARO2-DCS-FI91601')
# (2.0208, 'ARO2-LIMS-S708@Sulfur')
# (1.1879, 'ARO2-LIMS-S708@A10+')
# (0.4516, 'ARO2-DCS-FI914B3')
# (0.0842, 'ARO2-LIMS-S708@Water')
# (0.0448, 'ARO2-DCS-FI914B2')
# (0.0312, 'ARO2-LIMS-S708@A9')
# (-1.6213, 'ARO2-LIMS-S708@Br.Index')
# (-2.6282, 'ARO2-DCS-FI91701')

# %% [markdown]
# Lasso

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

features_names = df_3[x_col].columns.tolist()
for j in y_col:
  print(j, ":")
  if j == "ARO2-DCS-PDI91101" or j == "ARO2-DCS-PDI91201":
    lasso = Lasso(alpha=0.001 ,positive=True)
  else:
    lasso = Lasso(alpha=0.01 ,positive=True)
  # lasso = Lasso(alpha=0.01 ,positive=True)
  lasso.fit(df_3.loc[df_3[j].notna(), x_col], df_3.loc[df_3[j].notna(), j])
  coef_list=sorted(zip(map(lambda x: round(x,4), lasso.coef_.reshape(-1)),features_names),reverse=True)
  for i in coef_list:
    print(i)

  print()
# Out:
# ARO2-DCS-PDI91101 :
# (3.3643, 'ARO2-DCS-FI91701')
# (0.3419, 'ARO2-DCS-FI91601')
# (0.0, 'ARO2-LIMS-S708@Water')
# (0.0, 'ARO2-LIMS-S708@Sulfur')
# (0.0, 'ARO2-LIMS-S708@Br.Index')
# (0.0, 'ARO2-LIMS-S708@A9')
# (0.0, 'ARO2-LIMS-S708@A10+')
# (0.0, 'ARO2-DCS-FI914B3')
# (0.0, 'ARO2-DCS-FI914B2')
#
# ARO2-DCS-PDI91201 :
# (2.1854, 'ARO2-DCS-FI91601')
# (1.4339, 'ARO2-DCS-FI91701')
# (0.1537, 'ARO2-DCS-FI914B3')
# (0.045, 'ARO2-LIMS-S708@Br.Index')
# (0.0, 'ARO2-LIMS-S708@Water')
# (0.0, 'ARO2-LIMS-S708@Sulfur')
# (0.0, 'ARO2-LIMS-S708@A9')
# (0.0, 'ARO2-LIMS-S708@A10+')
# (0.0, 'ARO2-DCS-FI914B2')
#
# ARO2-LIMS-s922@PX :
# (0.5461, 'ARO2-DCS-FI91601')
# (0.0, 'ARO2-LIMS-S708@Water')
# (0.0, 'ARO2-LIMS-S708@Sulfur')
# (0.0, 'ARO2-LIMS-S708@Br.Index')
# (0.0, 'ARO2-LIMS-S708@A9')
# (0.0, 'ARO2-LIMS-S708@A10+')
# (0.0, 'ARO2-DCS-FI91701')
# (0.0, 'ARO2-DCS-FI914B3')
# (0.0, 'ARO2-DCS-FI914B2')
#
# ARO2-LIMS-s922@MX :
# (2493.9392, 'ARO2-DCS-FI914B3')
# (1533.1554, 'ARO2-LIMS-S708@Br.Index')
# (0.0, 'ARO2-LIMS-S708@Water')
# (0.0, 'ARO2-LIMS-S708@Sulfur')
# (0.0, 'ARO2-LIMS-S708@A9')
# (0.0, 'ARO2-LIMS-S708@A10+')
# (0.0, 'ARO2-DCS-FI91701')
# (0.0, 'ARO2-DCS-FI91601')
# (0.0, 'ARO2-DCS-FI914B2')
#
# ARO2-LIMS-S907@PX :
# (7.239, 'ARO2-LIMS-S708@Sulfur')
# (3.306, 'ARO2-DCS-FI91601')
# (0.7099, 'ARO2-DCS-FI914B2')
# (0.0, 'ARO2-LIMS-S708@Water')
# (0.0, 'ARO2-LIMS-S708@Br.Index')
# (0.0, 'ARO2-LIMS-S708@A9')
# (0.0, 'ARO2-LIMS-S708@A10+')
# (0.0, 'ARO2-DCS-FI91701')
# (0.0, 'ARO2-DCS-FI914B3')
#
# ARO2-LIMS-S905@PX :
# (0.3109, 'ARO2-LIMS-S708@Br.Index')
# (0.0, 'ARO2-LIMS-S708@Water')
# (0.0, 'ARO2-LIMS-S708@Sulfur')
# (0.0, 'ARO2-LIMS-S708@A9')
# (0.0, 'ARO2-LIMS-S708@A10+')
# (0.0, 'ARO2-DCS-FI91701')
# (0.0, 'ARO2-DCS-FI91601')
# (0.0, 'ARO2-DCS-FI914B3')
# (0.0, 'ARO2-DCS-FI914B2')
#
# ARO2-DCS-PX@Recovery :
# (7.8702, 'ARO2-DCS-FI91601')
# (0.2976, 'ARO2-LIMS-S708@Sulfur')
# (0.0, 'ARO2-LIMS-S708@Water')
# (0.0, 'ARO2-LIMS-S708@Br.Index')
# (0.0, 'ARO2-LIMS-S708@A9')
# (0.0, 'ARO2-LIMS-S708@A10+')
# (0.0, 'ARO2-DCS-FI91701')
# (0.0, 'ARO2-DCS-FI914B3')
# (0.0, 'ARO2-DCS-FI914B2')
